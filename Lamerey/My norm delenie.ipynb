# %%
import matplotlib.pyplot as plt
from numpy import *
import math
a=2.65
x1=0.7
def ff(x):
        return (a*x)%1
#b=a*x1*(1-x1)/x1
k=x1/((a*x1)%1)
def fl(x):
        return x
def f2(x):
    return (a*((a*x)%1))%1
x=-1.57
y=0
Y=[]
X=[]
for i in arange(1,30,1):
        X.append(x)
        Y.append(y)
        y=ff(x)
        X.append(x)
        Y.append(y)
        x=y*k
plt.title('Паутинная диаграмма логистической \n функции λx(1-x) при λ = '+str(a))
plt.plot(X,Y,'r')
x1=arange(0,1,0.003)
y1=[ff(x) for x in x1]
y2=[fl(x) for x in x1]
y3=[f2(x) for x in x1]
plt.plot(x1,y1,'b')
plt.plot(x1,y2,'g')
plt.plot(x1,y3,'k')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from numpy import *
import math
def Gor(a,z,M):
    # a=2.65
    x1=M
    def ff(x):
        return (a*x)%1
    #b=a*x1*(1-x1)/x1
    k=x1/((a*x1)%1)
    def fl(x):
        return x
    def f2(x):
        return (a*((a*x)%1))%1
    x=z
    y=0
    Y=[]
    X=[]
    for i in arange(1,30,1):
                X.append(x)
                Y.append(y)
                y=ff(x)
                X.append(x)
                Y.append(y)
                x=y*k
    plt.title('Паутинная диаграмма \n функции y{Ax} при A = '+str(a))
    plt.plot(X,Y,'r')
    x1=arange(0,1,0.01)
    y1=[ff(x) for x in x1]
    y2=[fl(x) for x in x1]
    y3=[f2(x) for x in x1]
    plt.plot(x1,y1,'b')
    plt.plot(x1,y2,'g')
    plt.plot(x1,y3,'k')
    plt.grid(True)
    plt.show()

# %%
Gor(3,1/4,0.5)

# %%
Gor(2.99999999,1/4,0.5)
